# %% [markdown]
# <a href="https://colab.research.google.com/github/nicobellic99/Adegbayibi-19431342/blob/master/CSY3010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
vidPath=r'nv232.MOV'
cap=cv2.VideoCapture(vidPath)
i=0
while(i<2):
  i+=1
  ret,frame=cap.read()
  cv2_imshow(frame)
cap.release()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F5D6F2F3E50>
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F5D6EA10B20>

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

def display_frames(frames):
  fig=plt.figure(figsize=(10,6))
  mov=[]
  for i in range(len(frames)):
    img=plt.imshow(frames[i],animated=True)
    plt.axis('off')
    mov.append([img])

  anime = animation.ArtistAnimation(fig,mov,interval=50,repeat_delay=1000)

  plt.close()
  return anime

# %%
vidPath=r'nv232.MOV'
cap=cv2.VideoCapture(vidPath)
frames=[]
i=0
while(1):
  ret,frame=cap.read()
  if ret:
    frame=cv2.resize(frame,dsize=(600,400))
    frame=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
    frames.append(frame)
  else:
    break
cap.release()

# %%
HTML(display_frames(frames).to_html5_video())
# Out:
# <video width="720" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
frame0_float=np.float32(frames[0])
frame1_float=np.float32(frames[1])

frame_diff=(frame0_float-frame1_float)**2
frame_diff_allchannel=np.sum(frame_diff,axis=2)

# %%
plt.figure(figsize = (10,6))
plt.subplot(221)
plt.imshow(frames[0])
plt.subplot(222)
plt.imshow(frames[1])
plt.subplot(223)
plt.imshow(frame_diff_allchannel>500,cmap='gray')

# %%
def display_diff_frames(frames,threshold):
  fig=plt.figure(figsize=(10,6))
  mov=[]
  for i in range(len(frames)):
    img=plt.imshow(frames[i]>int(threshold),cmap='gray',animated=True)
    plt.axis('off')
    mov.append([img])

  anime = animation.ArtistAnimation(fig,mov,interval=50,repeat_delay=1000)

  plt.close()
  return anime

# %%
pip install cvlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 10.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for cvlib: filename=cvlib-0.2.7-py3-none-any.whl size=10046383 sha256=014b90a7599595bfe9e23902d14f7ab10b9e574bbeb437c29f9391e07253c95e
#   Stored in directory: /root/.cache/pip/wheels/bb/11/55/82ced947752cc4056335a4ee9c304a93d43ce857230538f0ae
# ...
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12081 sha256=2f90eccdb653677264c12fd717e3e828bab54c37cbfef2b1150834f0be0a6eed
#   Stored in directory: /root/.cache/pip/wheels/2c/67/ed/d84123843c937d7e7f5ba88a270d11036473144143355e2747
# Successfully built cvlib progressbar
# ...
